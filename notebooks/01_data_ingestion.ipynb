# %%
import pandas as pd
import numpy as np
df=pd.read_csv("../data/raw/01_fund_master.csv")
print(df.head())

# %%
print("Rows and Columns:")
print(df.shape)

# %%
print(df.dtypes)

# %%
df.duplicated().sum()
